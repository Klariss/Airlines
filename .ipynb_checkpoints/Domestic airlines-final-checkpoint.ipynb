# %%
# importing packages

# %%
from pandas import DataFrame, read_csv
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Dataset preparation

# %%
#reading xlsx file into Jupyter notebook
file = 'DomesticAirlines_OnTimePerformance_data.xlsx'
df = pd.read_excel(file)
df.head()
# Out:
#                  Route Departing_Port Arriving_Port       Airline  \
# 0    Adelaide-Brisbane       Adelaide      Brisbane  All Airlines
# 1    Adelaide-Canberra       Adelaide      Canberra  All Airlines
# 2  Adelaide-Gold Coast       Adelaide    Gold Coast  All Airlines
# 3   Adelaide-Melbourne       Adelaide     Melbourne  All Airlines
# 4       Adelaide-Perth       Adelaide         Perth  All Airlines
#
#    Sectors_Scheduled  Sectors_Flown  Cancellations  Departures_On_Time  \
# 0                275            275              0                 254
# 1                 70             70              0                  63
# 2                 78             77              1                  73
# 3                732            719             13                 652
# 4                221            221              0                 201
#
#    Arrivals_On_Time  Departures_Delayed  Arrivals_Delayed  Year  Month_Num
# ...

# %%
# types of features in the dataset
df.dtypes
# Out:
# Route                 object
# Departing_Port        object
# Arriving_Port         object
# Airline               object
# Sectors_Scheduled      int64
# Sectors_Flown          int64
# Cancellations          int64
# Departures_On_Time     int64
# Arrivals_On_Time       int64
# Departures_Delayed     int64
# Arrivals_Delayed       int64
# Year                   int64
# Month_Num              int64
# dtype: object

# %%
#checking for missing values
df.isnull().sum().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#        Sectors_Scheduled  Sectors_Flown  Cancellations  Departures_On_Time  \
# count       21744.000000   21744.000000   21744.000000        21744.000000
# mean          325.199411     319.589956       5.609455          270.803532
# std          2246.816650    2208.712288      40.431329         1877.864283
# min             1.000000       1.000000       0.000000            0.000000
# 25%            34.000000      33.000000       0.000000           29.000000
# 50%            89.000000      88.000000       0.000000           73.000000
# 75%           173.000000     170.000000       2.000000          143.000000
# max         50949.000000   49908.000000    1528.000000        43537.000000
#
#        Arrivals_On_Time  Departures_Delayed  Arrivals_Delayed          Year  \
# count      21744.000000        21744.000000      21744.000000  21744.000000
# mean         268.373620           48.786424         51.216336   2016.267292
# ...

# %%
df.shape
# Out:
# (21744, 13)

# %%
#13 feature and more than 20000 rows clean data

# %%
df.head()
# Out:
#                  Route Departing_Port Arriving_Port       Airline  \
# 0    Adelaide-Brisbane       Adelaide      Brisbane  All Airlines
# 1    Adelaide-Canberra       Adelaide      Canberra  All Airlines
# 2  Adelaide-Gold Coast       Adelaide    Gold Coast  All Airlines
# 3   Adelaide-Melbourne       Adelaide     Melbourne  All Airlines
# 4       Adelaide-Perth       Adelaide         Perth  All Airlines
#
#    Sectors_Scheduled  Sectors_Flown  Cancellations  Departures_On_Time  \
# 0                275            275              0                 254
# 1                 70             70              0                  63
# 2                 78             77              1                  73
# 3                732            719             13                 652
# 4                221            221              0                 201
#
#    Arrivals_On_Time  Departures_Delayed  Arrivals_Delayed  Year  Month_Num
# ...

# %%
# function to check if the "Departing_Port" and "Arriving_Port" are always the same as the "Route" feature
# because flights can be diverted
# can be used later to check the future data 

def check_route(row):
    if row['Route'] != row['Departing_Port'] + "-" + row['Arriving_Port']:
        return "Route changed"
    else:
        return "Route didn't changed"
    

df['Route_check'] = df.apply(check_route, axis=1)
df['Route_check'].value_counts()
# Out:
# Route didn't changed    21744
# Name: Route_check, dtype: int64

# %%
# checks for incorrect data in the dataset

# %%
def check_arrival(row):
    if row['Route'] != row['Departing_Port'] + "-" + row['Arriving_Port']:
        return "Route changed"
    else:
        return "Route didn't changed"
    

df['Route_check'] = df.apply(check_route, axis=1)
df['Route_check'].value_counts()
# Out:
# Route didn't changed    21744
# Name: Route_check, dtype: int64

# %%
df.Route.value_counts().head()
# Out:
# All Ports-All Ports    328
# Brisbane-Cairns        246
# Adelaide-Sydney        246
# Cairns-Brisbane        246
# Sydney-Adelaide        246
# Name: Route, dtype: int64

# %%
df.Airline.value_counts()
# Out:
# All Airlines                          5381
# Virgin Australia                      4737
# QantasLink                            3111
# Jetstar                               2869
# Qantas                                2657
# Tigerair Australia                    1477
# Virgin Australia Regional Airlines     831
# Regional Express                       681
# Name: Airline, dtype: int64

# %%
# possible meaning of "All Ports-All Ports" and "All Airline" 
# Probably these cathegories refer to all the other possible arrival/departure ports and airline types in the Austral region.
# In case of "Route" the smallest amount is 21, "Airline" the smallest is 681, 
# any smaller group is possible to considered too small to have a different cathegory

# %%
df.Year.value_counts().head()
# Out:
# 2017    6470
# 2016    6342
# 2015    6174
# 2018    2758
# Name: Year, dtype: int64

# %%
# 2018 has only data till May, so instead of looking at the years separetly, look for timeseries

# %%
# Feature engereering
# creating date

import time
import datetime



def creating_date(row):
    return datetime.datetime(year=row['Year'], month=row['Month_Num'], day=1)
   

df['Date'] = df.apply(creating_date, axis=1)

# %%
#EDA

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(), annot=True)
plt.show()

# %%
def sum_delay(row):
    return row['Departures_Delayed'] + row['Arrivals_Delayed']

df['Delay_sum'] = df.apply(sum_delay, axis=1)

# %%
df.Departing_Port.value_counts().head()
# Out:
# Sydney       3633
# Brisbane     3064
# Melbourne    2500
# Perth        1989
# Adelaide     1357
# Name: Departing_Port, dtype: int64

# %%
df.Arriving_Port.value_counts().head()
# Out:
# Sydney       3633
# Brisbane     3063
# Melbourne    2501
# Perth        1989
# Adelaide     1357
# Name: Arriving_Port, dtype: int64

# %%
# statistical description of the airlines

# %%
df.groupby(['Airline']).Sectors_Flown.describe()
# Out:
#                                      count        mean          std   min  \
# Airline
# All Airlines                        5381.0  645.713064  4068.683478  25.0
# Jetstar                             2869.0  187.434995   834.830146  12.0
# Qantas                              2657.0  274.446744  1115.410499   1.0
# QantasLink                          3111.0  226.556091  1127.702529   1.0
# Regional Express                     681.0  450.876652  1408.323328   3.0
# Tigerair Australia                  1477.0  121.718348   361.615281   3.0
# Virgin Australia                    4737.0  195.493139  1057.270778   1.0
# Virgin Australia Regional Airlines   831.0  108.223827   313.083184   2.0
#
#                                       25%    50%    75%      max
# Airline
# All Airlines                        109.0  199.0  321.0  49908.0
# Jetstar                              30.0   72.0  114.0   8449.0
# Qantas                               31.0   71.0  185.0   9907.0
# ...

# %%
df.groupby(['Airline']).Sectors_Flown.apply(np.sum).plot(kind='pie', x= 50, autopct='%1.1f%%', 
                                                         startangle=90, figsize=(15, 15), 
                                                         colormap='spring').set_ylabel('')
# Out:
# Text(0,0.5,'')

# %%
df.groupby(['Airline']).Delay_sum.apply(np.sum).plot(kind='pie', x= 50, autopct='%1.1f%%', 
                                                         startangle=90, figsize=(15, 15), 
                                                     colormap='winter').set_ylabel('')
# Out:
# Text(0,0.5,'')

# %%
df.groupby(['Airline']).Sectors_Scheduled.apply(np.sum).plot(kind='pie', x= 50, autopct='%1.1f%%', 
                                                         startangle=90, figsize=(15, 15), 
                                                     colormap='winter').set_ylabel('')
# Out:
# Text(0,0.5,'')

# %%
df.groupby(['Airline']).Departures_On_Time.apply(np.sum).plot(kind='pie', x= 50, autopct='%1.1f%%', 
                                                         startangle=90, figsize=(15, 15), 
                                                     colormap='winter').set_ylabel('')
# Out:
# Text(0,0.5,'')

# %%
df.Airline.value_counts().plot(kind='bar', width=0.6,rot=0, figsize=(22, 9), colormap='plasma');
plt.title("Airline routes")
# Out:
# Text(0.5,1,'Airline routes')

# %%
df.head()
# Out:
#                  Route Departing_Port Arriving_Port       Airline  \
# 0    Adelaide-Brisbane       Adelaide      Brisbane  All Airlines
# 1    Adelaide-Canberra       Adelaide      Canberra  All Airlines
# 2  Adelaide-Gold Coast       Adelaide    Gold Coast  All Airlines
# 3   Adelaide-Melbourne       Adelaide     Melbourne  All Airlines
# 4       Adelaide-Perth       Adelaide         Perth  All Airlines
#
#    Sectors_Scheduled  Sectors_Flown  Cancellations  Departures_On_Time  \
# 0                275            275              0                 254
# 1                 70             70              0                  63
# 2                 78             77              1                  73
# 3                732            719             13                 652
# 4                221            221              0                 201
#
#    Arrivals_On_Time  Departures_Delayed  Arrivals_Delayed  Year  Month_Num  \
# ...

# %%
# comparing 'Cancellations' to 'Sectors_Scheduled'
scheduled_by_airlines = df.groupby(['Airline']).Sectors_Scheduled.apply(np.sum).sort_values(ascending=False)
cancellation_by_airlines = df.groupby(['Airline']).Cancellations.apply(np.sum).sort_values(ascending=False)
Cancellation_per_by_airlines = (cancellation_by_airlines / scheduled_by_airlines.sum()) * 100
Cancellation_per_by_airlines.plot(kind='bar', width=0.6,rot=0, figsize=(22, 9));

# %%
# comparing the 'Arrivals_On_Time' and 'Arrivals_Delayed' to 'Sectors_Scheduled'
cancellation_by_airlines = df.groupby(['Airline']).Cancellations.apply(np.sum).sort_values(ascending=False)
cancellation_by_airlines.plot(kind='bar', width=0.6,rot=0, figsize=(22, 9));

# %%
delays_by_airlines = df.groupby(['Airline'])['Departures_Delayed', 
                                                'Arrivals_Delayed'].apply(np.sum)
delays_by_airlines.loc[["All Airlines"]].apply(np.sum).plot(kind='pie', x= 50, autopct='%1.1f%%',startangle=90, figsize=(10, 10), 
                                                    colors=['navy','aqua'], subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x11b6c3a20>],
#       dtype=object)

# %%
# dropping 'All Airlines' in order to see airlines separetly
delays_by_airlines = delays_by_airlines.drop("All Airlines", axis=0)

# %%
delays_by_airlines.plot(kind='bar', width=0.6,rot=0, figsize=(22, 9), color=['navy','aqua','turquoise']);

# %%
cancelled_by_airlines = df.groupby(['Airline']).Cancellations.apply(np.sum).sort_values(ascending=False)
cancelled_by_airlines.plot(kind='bar', width=0.6,rot=0, figsize=(22, 9));

# %%
delay_by_airlines = df.groupby(['Airline']).Delay_sum.apply(np.sum).sort_values(ascending=False)
delay_by_airlines.plot(kind='bar', width=0.6,rot=0, figsize=(22, 9));

# %%
delay_by_airlines = df.groupby(['Airline']).Departures_Delayed.apply(np.sum).sort_values(ascending=False)
delay_by_airlines.plot(kind='bar', width=0.6,rot=0, figsize=(22, 9));

# %%
ontime_by_airlines = df.groupby(['Airline']).Departures_On_Time.apply(np.sum).sort_values(ascending=False)
ontime_by_airlines.plot(kind='bar', width=0.6,rot=0, figsize=(22, 9));

#cancelled_by_airlines = cancelled_by_airlines.groupby(['Airline'])['Cancellations','Delay_sum', 
# 'Sectors_Scheduled'].apply(np.sum).sort_values(by='Sectors_Scheduled')
#cancelled_by_airlines.plot(kind='bar', width=0.6,rot=0, figsize=(22, 9));

# %%
# timeseries

# %%
# percentages of all to get them on a scale
# getting years and months together

# then in timeseries showing delay, on time and cancellations

# %%
df.head(3)
# Out:
#                  Route Departing_Port Arriving_Port       Airline  \
# 0    Adelaide-Brisbane       Adelaide      Brisbane  All Airlines
# 1    Adelaide-Canberra       Adelaide      Canberra  All Airlines
# 2  Adelaide-Gold Coast       Adelaide    Gold Coast  All Airlines
#
#    Sectors_Scheduled  Sectors_Flown  Cancellations  Departures_On_Time  \
# 0                275            275              0                 254
# 1                 70             70              0                  63
# 2                 78             77              1                  73
#
#    Arrivals_On_Time  Departures_Delayed  Arrivals_Delayed  Year  Month_Num  \
# 0               257                  21                18  2015          1
# 1                63                   7                 7  2015          1
# 2                72                   4                 5  2015          1
#
#             Route_check       Date  Delay_sum
# 0  Route didn't changed 2015-01-01         39
# ...

# %%
# comparing the 'Departures_On_Time' and 'Departures_Delayed' to 'Sectors_Scheduled'
Scheduled_by_date = df.groupby(['Date']).Sectors_Scheduled.apply(np.sum)
Departures_On_Time_by_date = df.groupby(['Date']).Departures_On_Time.apply(np.sum)
Arrivals_On_Time_by_date = df.groupby(['Date']).Arrivals_On_Time.apply(np.sum)


Departures_On_Time_by_date = (Departures_On_Time_by_date / Scheduled_by_date.sum()) * 100
Arrivals_On_Time_by_date = (Arrivals_On_Time_by_date / Scheduled_by_date.sum()) * 100


On_Time_perf = pd.DataFrame(Departures_On_Time_by_date, Arrivals_On_Time_by_date)
#On_Time_perf.plot(kind='bar', width=0.6,rot=0, figsize=(22, 9));

df['Departures_Delay_%'] = (df.Departures_Delayed / df.Departures_Delayed.sum()) * 100
df['Arrivals_Delay_%'] = (df.Arrivals_Delayed / df.Arrivals_Delayed.sum()) * 100
df['Departures_On_Time_%'] = (df.Departures_On_Time / df.Departures_On_Time.sum()) * 100
df['Arrivals_On_Time_%'] = (df.Arrivals_On_Time / df.Arrivals_On_Time.sum()) * 100
df['Cancellations_%'] = (df.Cancellations / df.Cancellations.sum()) * 100


cancelled_by_airlines = df.groupby(['Date'])['Departures_On_Time_%', 
                                                'Arrivals_On_Time_%'].apply(np.sum).plot(figsize=(18, 6))

# df.groupby('Date')['Arrivals_On_Time', 'Departures_On_Time'].sum().plot(figsize=(18, 6))

# %%
# first departures

# %%
# second arrivals if there's any difference with departures
# then explaining the not consecquent traffic reasons (bigger number of flights)

# %%
df.head(3)
# Out:
#                  Route Departing_Port Arriving_Port       Airline  \
# 0    Adelaide-Brisbane       Adelaide      Brisbane  All Airlines
# 1    Adelaide-Canberra       Adelaide      Canberra  All Airlines
# 2  Adelaide-Gold Coast       Adelaide    Gold Coast  All Airlines
#
#    Sectors_Scheduled  Sectors_Flown  Cancellations  Departures_On_Time  \
# 0                275            275              0                 254
# 1                 70             70              0                  63
# 2                 78             77              1                  73
#
#    Arrivals_On_Time  Departures_Delayed       ...         Year  Month_Num  \
# 0               257                  21       ...         2015          1
# 1                63                   7       ...         2015          1
# 2                72                   4       ...         2015          1
#
#             Route_check       Date Delay_sum  Departures_Delay_%  \
# ...

# %%
df['Departures_Delay_percent'] = df.Departures_Delayed / df.Sectors_Scheduled.sum() * 100
#df['Arrivals_Delay_percent'] = (df.Arrivals_Delayed / df.Sectors_Scheduled).sum() * 100
#df['Departures_On_Time_%'] = (df.Departures_On_Time / df.Sectors_Scheduled.sum()) * 100
#df['Arrivals_On_Time_%'] = (df.Arrivals_On_Time / df.Sectors_Scheduled.sum()) * 100
#df['Cancellations_%'] = (df.Cancellations / df.Sectors_Scheduled.sum()) * 100



delay = df.groupby(['Date'])['Departures_Delay_percent'].apply(np.sum)
delay.plot(figsize=(18, 6))

# %%
# Plot delays over time
df.groupby('Date')['Arrivals_Delayed', 'Departures_Delayed'].sum().plot(figsize=(18, 6))

# %%
# Plot delays over time
df.groupby('Date')['Departures_Delayed'].sum().plot(figsize=(18, 6))

# %%
df.groupby('Date')['Arrivals_Delayed', 'Departures_Delayed'].sum().plot(figsize=(18, 6))

# %%
df.groupby('Date')['Sectors_Scheduled', 'Arrivals_Delayed', 'Departures_Delayed', 'Cancellations'].sum().plot(figsize=(18, 6))

# %%
df.groupby('Date')['Sectors_Scheduled', 'Arrivals_Delayed', 'Departures_Delayed'].sum().plot(figsize=(18, 10))

# %%
df.groupby('Date')['Arrivals_On_Time', 'Departures_On_Time'].sum().plot(figsize=(18, 6))

# %%
df.head()
# Out:
#                  Route Departing_Port Arriving_Port       Airline  \
# 0    Adelaide-Brisbane       Adelaide      Brisbane  All Airlines
# 1    Adelaide-Canberra       Adelaide      Canberra  All Airlines
# 2  Adelaide-Gold Coast       Adelaide    Gold Coast  All Airlines
# 3   Adelaide-Melbourne       Adelaide     Melbourne  All Airlines
# 4       Adelaide-Perth       Adelaide         Perth  All Airlines
#
#    Sectors_Scheduled  Sectors_Flown  Cancellations  Departures_On_Time  \
# 0                275            275              0                 254
# 1                 70             70              0                  63
# 2                 78             77              1                  73
# 3                732            719             13                 652
# 4                221            221              0                 201
#
#    Arrivals_On_Time  Departures_Delayed            ...             Month_Num  \
# ...

# %%
# Airport performance delay

Departing_port_delay = pd.DataFrame(data=df.groupby('Departing_Port')['Sectors_Scheduled', 'Departures_Delayed'].sum())


Departing_port_delay['Departing_port_perf'] = (Departing_port_delay.Departures_Delayed / Departing_port_delay.Sectors_Scheduled) * 100


Departing_port_delay['Departing_port_perf'].sort_values(ascending=False).plot(kind='bar', width=0.6, figsize=(18, 8));

# %%
# Airport performance cancellation

Departing_port_canc = pd.DataFrame(data=df.groupby('Departing_Port')['Sectors_Scheduled', 'Cancellations'].sum())


Departing_port_canc['Departing_port_perf'] = (Departing_port_canc.Cancellations / Departing_port_canc.Sectors_Scheduled) * 100


Departing_port_canc['Departing_port_perf'].sort_values(ascending=False).plot(kind='bar', width=0.6, figsize=(18, 8));

# %%
# Airline performance cancellation

Airline_canc = pd.DataFrame(data=df.groupby('Airline')['Sectors_Scheduled', 'Cancellations'].sum())


Airline_canc['Airline_perf'] = (Airline_canc.Cancellations / Airline_canc.Sectors_Scheduled) * 100


Airline_canc['Airline_perf'].sort_values(ascending=False).plot(kind='bar', width=0.6, figsize=(18, 8));

# %%
# Airline performance delay

Airline_delay = pd.DataFrame(data=df.groupby('Airline')['Sectors_Scheduled', 'Departures_Delayed'].sum())


Airline_delay['Airline_perf'] = (Airline_delay.Departures_Delayed / Airline_delay.Sectors_Scheduled) * 100


Airline_delay['Airline_perf'].sort_values(ascending=False).plot(kind='bar', width=0.6, figsize=(18, 8));

# %%
df.groupby('Departing_Port')['Departures_Delay_percent'].apply(np.sum).sort_values(ascending=False).head()
# Out:
# Departing_Port
# All Ports    8.233755
# Sydney       1.721336
# Melbourne    1.357123
# Brisbane     0.880651
# Adelaide     0.322579
# Name: Departures_Delay_percent, dtype: float64

# %%
Departures_Delay_percent.sort_values(ascending=False).head()
# Out:
# 14119    0.146794
# 9347     0.141505
# 17873    0.137743
# 16247    0.136767
# 11989    0.128692
# Name: Departures_Delayed, dtype: float64

# %%
# Total Industry On Time Performance for four years ended May of 2018

# %%
delay_by_years = df.groupby(['Year']).Delay_sum.apply(np.sum).sort_values(ascending=False)
delay_by_years.plot(kind='bar', width=0.6,rot=0, figsize=(12, 6));

# %%
#delay_by_months = df.groupby(['Month_Num']).Delay_sum.apply(np.sum)
#delay_by_months.plot(kind='bar', width=0.6,rot=0, figsize=(12, 6));

# %%
scheaduled_by_months = df.groupby(['Month_Num']).Sectors_Scheduled.apply(np.sum)
scheaduled_by_months.plot(kind='bar', width=0.6,rot=0, figsize=(12, 6));

# %%
#cancellations_by_months = df.groupby(['Month_Num']).Cancellations.apply(np.sum)
#cancellations_by_months.plot(kind='bar', width=0.6,rot=0, figsize=(12, 6));

# %%
# monthly delay trend

# %%
df.Month_Num.value_counts()
# Out:
# 1     2128
# 3     2124
# 4     2116
# 2     2114
# 5     2108
# 12    1632
# 11    1606
# 10    1606
# 9     1598
# 8     1574
# 6     1574
# 7     1564
# Name: Month_Num, dtype: int64

# %%
cancellations_by_months = df.groupby(['Departing_Port']).Sectors_Flown.apply(np.sum).sort_values(ascending=False)
cancellations_by_months.plot(kind='bar', width=0.6, figsize=(12, 6));

# %%
cancellations_by_months = df.groupby(['Departing_Port']).Cancellations.apply(np.sum).sort_values(ascending=False)
cancellations_by_months.plot(kind='bar', width=0.6, figsize=(12, 6));

# %%
fig = plt.figure(figsize=(8,6))
ax = fig.gca()

sns.regplot('Cancellations', 'Delay_sum', data=df, fit_reg=True, 
                 color='steelblue', ax=ax)

ax.set_title('Cancellations vs Delay_sum')
plt.show()
# Out:
# /Users/klara/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
# looking for distances and delay

# %%
fig = plt.figure(figsize=(8,6))
ax = fig.gca()

sns.regplot('Cancellations', 'Delay_sum', data=df, fit_reg=True, 
                 color='steelblue', ax=ax)

ax.set_title('Cancellations vs Delay_sum')
plt.show()

# %%
# first 5 months

# %%
# size of dots

# %%
data = {'a': df.Delay_sum,
        'c': df.Cancellations}

data['b'] = data['c']

plt.scatter('a','b', data=data)
plt.xlabel('Delays')
plt.ylabel('Cancellations')
plt.show()

# %%
data = {'a': np.arange(50),
        'c': np.random.randint(0, 50, 50),
        'd': np.random.randn(50)}
data['b'] = data['a'] + 10 * np.random.randn(50)
data['d'] = np.abs(data['d']) * 100

plt.scatter('a', 'b', c='c', s='d', data=data)
plt.xlabel('entry a')
plt.ylabel('entry b')
plt.show()

# %%
df[df.Airline == 'All Airlines'].groupby(['Year', 'Month_Num']).count()

# %%
df.hist('Month_Num')
